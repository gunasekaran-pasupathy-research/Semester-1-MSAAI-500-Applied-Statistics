# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
students = pd.read_table('http://stat4ds.rwth-aachen.de/data/Students.dat',
                          sep="\\s+")

# %%
students.head()
# Out:
#    subject  gender  age  hsgpa  cogpa  dhome  dres    tv  sport  news  aids  \
# 0        1       0   32    2.2    3.5      0   5.0   3.0      5     0     0
# 1        2       1   23    2.1    3.5   1200   0.3  15.0      7     5     6
# 2        3       1   27    3.3    3.0   1300   1.5   0.0      4     3     0
# 3        4       1   35    3.5    3.2   1500   8.0   5.0      5     6     3
# 4        5       0   23    3.1    3.5   1600  10.0   6.0      6     3     0
#
#    veg  affil  ideol  relig  abor  affirm  life
# 0    0      2      6      2     0       0     1
# 1    1      1      2      1     1       1     3
# 2    1      1      2      2     1       1     3
# 3    0      3      4      1     1       1     2
# 4    0      3      1      0     1       0     2

# %%
gender = students["gender"].replace({0: "male", 1: "female"})

# %%
# students.rename(columns={"gender": "a", "B": "c"})

# %%
gender
# Out:
# 0       male
# 1     female
# 2     female
# 3     female
# 4       male
# 5       male
# 6       male
# 7     female
# 8       male
# 9       male
# 10      male
# 11    female
# 12      male
# 13      male
# 14    female
# 15    female
# 16    female
# 17      male
# 18      male
# 19    female
# 20    female
# 21    female
# 22      male
# 23    female
# 24      male
# 25    female
# 26      male
# 27    female
# 28      male
# 29    female
# 30      male
# 31    female
# 32      male
# 33    female
# 34    female
# 35      male
# 36      male
# 37      male
# 38      male
# 39      male
# 40      male
# 41      male
# 42    female
# 43      male
# 44    female
# 45    female
# 46    female
# 47      male
# 48    female
# 49    female
# 50      male
# 51    female
# 52    female
# 53    female
# 54    female
# 55    female
# 56      male
# 57      male
# 58    female
# 59    female
# Name: gender, dtype: object

# %%
gender.value_counts(1).round(2).plot(kind="bar", width=0.9, rot=0, color="green")
plt.title("Student Gender Proportion Comparison")
plt.xlabel("Gender")
plt.ylabel("Proportion")
plt.show()

gender.value_counts()
# Out:
# gender
# female    31
# male      29
# Name: count, dtype: int64

# %%
students["age"].describe()
# Out:
# count    60.000000
# mean     29.166667
# std       8.475621
# min      22.000000
# 25%      24.000000
# 50%      26.500000
# 75%      31.000000
# max      71.000000
# Name: age, dtype: float64

# %%
students["age"].hist(bins=10, edgecolor="black", grid=False)
plt.show()

# %% [markdown]
# The equation for linear regression is $\hat{y} = \beta_0 + \beta_1x_1 ...$
